# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_csv('./Data/A_smart_phones.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             Product_Name   Price Rating  Memory  \
# 0           0  Xiaomi Redmi Note 9 Pro  252.00    4.9  128 GB
# 1           1  Xiaomi Redmi Note 9 Pro  249.00    4.8  128 GB
# 2           2          Huawei P40 Lite  199.00    4.6   128GB
# 3           3  Xiaomi Redmi Note 9 Pro  239.00      5  128 GB
# 4           4      Samsung Galaxy M31s  317.00      5  128 GB
#
#                Color
# 0  Interstellar Grey
# 1              Green
# 2     Midnight Black
# 3              White
# 4       Mirage black

# %% [markdown]
# Clean Data:

# %%
df = df[['Product_Name', 'Price', 'Rating', 'Memory', 'Color']]

# %% [markdown]
# Setting 'Price' as a float type:

# %%
type(df['Price'][20])
# Out:
# str

# %%
def to_float_num(s):
    if s != '-':
        return float(s)
    else:
        return s

# %%
df.Price = df.Price.apply(lambda x: to_float_num(x))

# %%
type(df['Price'][20])
# Out:
# float

# %% [markdown]
# Fix column 'Memory':

# %%
def normalize_memory(x):
    x = x.lower().replace('gb', '')
    try:
        return int(x)
    except:
        return '-'

# %%
df['Memory_GB'] = df['Memory'].apply(lambda x: normalize_memory(x))

# %%
df.Memory_GB.value_counts()
# Out:
# -      256
# 128    200
# 64     151
# 32      88
# 256     69
# 16      42
# 512     17
# 8       12
# 4        2
# 24       1
# 12       1
# 3        1
# Name: Memory_GB, dtype: int64

# %%
df = df.drop(['Memory'], axis=1)

# %% [markdown]
# Fix column 'Color':

# %%
df.Color = df.Color.apply(lambda x: x.lower())

# %%
threshhold = 10
is_rare = df.Color.value_counts() < 10
rare = is_rare[is_rare].index

# %%
are_rare_rows = df["Color"].isin(rare)
are_rare_rows[are_rare_rows].index
# Out:
# Int64Index([  0,   4,   5,   8,  10,  11,  13,  15,  16,  17,
#             ...
#             823, 824, 825, 827, 828, 831, 832, 835, 837, 838],
#            dtype='int64', length=263)

# %%
rare_colors = df.iloc[are_rare_rows[are_rare_rows].index]

# %%
rare_colors
# Out:
#                       Product_Name   Price Rating                  Color  \
# 0          Xiaomi Redmi Note 9 Pro     252    4.9      interstellar grey
# 4              Samsung Galaxy M31s     317      5           mirage black
# 5                   Xiaomi Redmi 9   149.5      5            carbon grey
# 8                  Xiaomi Redmi 9C  118.51      -          twilight blue
# 10           Xiaomi Mi 10T Lite 5G     319      5             pearl gray
# ..                             ...     ...    ...                    ...
# 831            Xiaomi Redmi Note 7       -    4.7            space black
# 832               Huawei Y5 (2019)       -    4.7           modern black
# 835                     Huawei Y5P       -      5           phantom blue
# 837  Išmanusis telefonas iPhone 6S       -      -  rožinio aukso spalvos
# 838   Išmanusis telefonas iPhone 7       -      -               auksinis
#
#     Memory_GB
# 0         128
# 4         128
# 5          64
# 8          32
# 10        128
# ..        ...
# 831         -
# 832        16
# 835        32
# 837        64
# 838        32
#
# [263 rows x 5 columns]

# %%
def normalize_color(x):
    if x == ('mėlyna' or 'mėlynas'):
        return 'blue'
    elif len(x) < 3:
        return '-'
    elif x == ('geltonas' or 'geltona'):
        return 'yellow'
    elif x == ('juodas' or 'juoda'):
        return 'black'
    elif x == ('oranžinis' or 'oranžinė'):
        return 'orange'
    elif x == ('pilkas' or 'pilka'):
        return 'grey'
    elif x == ('auksinis' or 'auksinė'):
        return 'gold'
    elif x == ('sidabrinis' or 'sidabrinė'):
        return 'silver'
    elif x == ('baltas' or 'balta'):
        return 'white'
    elif x == ('rožinio aukso spalvos'):
        return 'pink gold'
    elif x == ('žalias' or 'žalia'):
        return 'green'
    elif '+' in x:
        return x.split('+')[0]
    elif x == 'dual sim':
        return '-'
    else:
        return x

# %%
df.Color = df.Color.apply(lambda x: normalize_color(x))

# %%
df.Color.value_counts()
# Out:
# -                 430
# black              64
# blue               42
# midnight black     19
# white              14
#                  ...
# coral red           1
# dark blue           1
# space blue          1
# sky blue            1
# frozen blue         1
# Name: Color, Length: 144, dtype: int64

# %%
df[100:150]
# Out:
#                             Product_Name   Price Rating              Color  \
# 100                       Xiaomi Redmi 9     132      5        ocean green
# 101                      Huawei P30 Lite  198.51    4.8                  -
# 102                       Xiaomi Redmi 9   132.4      5      sunset purple
# 103                         OnePlus Nord  502.91      -                  -
# 104                   Samsung Galaxy S10  549.49      -                  -
# 105                 Blackview BV9900 PRO     522      -              black
# 106             Samsung Galaxy A71 128GB     411      5                  -
# 107                        Blackview A80      74      5                  -
# 108                      Apple iPhone XR     658      -                  -
# 109                       Xiaomi Redmi 9     135      5        carbon grey
# 110                      Apple iPhone 11     804      5                  -
# 111                     Huawei Y6 (2019)     104    4.6     midnight black
# 112                            Meizu M6T   69.97      5                  -
# 113                  Samsung Galaxy A20e     147    4.4              black
# 114                   Samsung Galaxy A71     380    4.9               blue
# 115                     Huawei Honor 20S     192      -              black
# 116                      Xiaomi Redmi 9A     101      5       granite gray
# 117                      Nokia 2720 Flip    85.9    4.3                red
# 118               Samsung Xcover 4s G398     209      5                  -
# 119                  Xiaomi Redmi Note 9     201    4.1        polar white
# 120                  Samsung Galaxy A20e  144.69    4.3               blue
# 121  Samsung Galaxy S8 Plius 64GB (G955)     488      -                  -
# 122                   Samsung Galaxy A51     275      5               blue
# 123            Huawei P Smart Pro (2019)     309      5  breathing cristal
# 124                   Samsung Galaxy A31     226      5  prism crush black
# 125                      Huawei P30 Lite     209    4.9                  -
# 126                   Alcatel 3L (5034D)      68      -                  -
# 127                Blackview BV9100 64GB  218.02      5                  -
# 128                              LG K51S     184      5              titan
# 129              Xiaomi Redmi Note 8 Pro     208    4.8       mineral grey
# 130                  Samsung Galaxy A21s     159      5               blue
# 131                   Samsung Galaxy S10     539    4.3                  -
# 132                  Samsung Galaxy A20s     144      5              black
# 133                  Samsung Galaxy A30s     195      5              white
# 134           Samsung Galaxy S20 Plus 4G     746      5       cosmic black
# 135                               LG K61  233.74      -              titan
# 136                           Huawei Y6P   118.7      5      emerald green
# 137                  Xiaomi Redmi Note 9   163.5      5        polar white
# 138                   Huawei P40 Lite 5G     220      -              black
# 139                           Huawei Y5P    93.5      -         mint green
# 140                Blackview BV5500 Plus      99      -             yellow
# 141              Samsung Galaxy S10 Lite     399    4.3                  -
# 142                  Xiaomi Redmi Note 9  181.88      5        no nfc grey
# 143            Xiaomi Redmi Note 8T 64GB     169    4.9                  -
# 144                              LG K50S     122      5              black
# 145                  Huawei P Smart 2019     161      5        aurora blue
# 146                 Xiaomi Redmi Note 9S   219.9    4.5                  -
# 147                  Samsung Galaxy A21s     165      5              white
# 148                  Samsung Galaxy M31s     324      -               blue
# 149              Samsung Galaxy S10 Lite     399      5                  -
#
#     Memory_GB
# 100        32
# 101       128
# 102        32
# 103       256
# 104       128
# 105       128
# 106         -
# 107        16
# 108       128
# 109        32
# 110       128
# 111         -
# 112         -
# 113        32
# 114       128
# 115       128
# 116        32
# 117         4
# 118        32
# 119       128
# 120        32
# 121         -
# 122       128
# 123       128
# 124        64
# 125       128
# 126         -
# 127         -
# 128        64
# 129         -
# 130        32
# 131       128
# 132        32
# 133       128
# 134       128
# 135       128
# 136        64
# 137        64
# 138       128
# 139        32
# 140        32
# 141       128
# 142       128
# 143         -
# 144        32
# 145         -
# 146       128
# 147        32
# 148       128
# 149       128

# %%
df.Rating.value_counts()
# Out:
# -      510
# 5      193
# 4.8     30
# 4.9     23
# 4       15
# 4.5     14
# 4.7     13
# 4.3     10
# 4.6      8
# 3        7
# 3.5      4
# 3.7      4
# 4.1      3
# 4.4      3
# 1        2
# 3.8      1
# Name: Rating, dtype: int64

# %% [markdown]
# Normalize Product_Name:

# %%
df.Product_Name = df.Product_Name.apply(lambda x: 
                      x.replace('Išmanusis telefonas ', '').replace('Išmanusis', ''))

# %%
df.drop(df[df['Product_Name'].apply(lambda x: x.strip().split(' ')[0]) == 'laikrodis'].index,
       inplace = True)

# %% [markdown]
# Save to .csv file:

# %%
df.to_csv('./Cleaned Data/Retailer_A_phones.csv', index=False)
